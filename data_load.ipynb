# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

filename = '/Users/ajay/Downloads/nyu_depth_v2_labeled.mat'

# Open the .mat file
with h5py.File(filename, 'r') as file:
    # List all groups
    print(list(file.keys()))
# Out:
# ['#refs#', '#subsystem#', 'accelData', 'depths', 'images', 'instances', 'labels', 'names', 'namesToIds', 'rawDepthFilenames', 'rawDepths', 'rawRgbFilenames', 'sceneTypes', 'scenes']

# %%
images = None
with h5py.File(filename, 'r') as file:
    # Assuming 'images' is the key for the image data
    images = file['images'][:]  # Load the entire dataset into memory

# %%
print(len(images))
# Out:
# 1449
